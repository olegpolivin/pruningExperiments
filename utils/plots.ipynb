# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
experiments_results = {
    "UnstructRandomPrun":
    {
        "accuracy": [0.9809, 0.9744, 0.9665, 0.9524, 0.9194, 0.8529, 0.4458, 0.1365],
        "compression_flops": [1, 1.3706, 1.9531, 2.9137, 4.6296, 8.0134, 15.625, 36.75],
        "compression_size": [1, 1.3695, 1.9455, 2.8927, 4.5614, 7.7750, 14.7368, 32.2124]
    },
    "UnstructPrunL1Norm":
    {
        "accuracy": [0.9809, 0.9824, 0.9818, 0.9781, 0.9698, 0.9543, 0.8555, 0.7565],
        "compression_flops": [1, 1.3706, 1.9531, 2.9137, 4.6296, 8.0134, 15.625, 36.75],
        "compression_size": [1, 1.3695, 1.9455, 2.8927, 4.5614, 7.7750, 14.7368, 32.2124]
    },
    "StructuredPrunL1Norm":
    {
        "accuracy": [0.9809, 0.9781, 0.9667, 0.9477, 0.9228, 0.753, 0.5095, 0.1135],
        "compression_flops": [1, 1.4268, 1.9976, 2.94, 4.98, 7.15, 16.34, 25.33],
        "compression_size": [1, 1.3561, 1.8934, 2.78, 4.23, 6.06, 11.97, 18.83]
    }
}

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
marker = ['o', 's', 'd']
for i, (key, results) in enumerate(experiments_results.items()):
    compression_flops = results["compression_flops"]
    accuracy = results["accuracy"]
    lbl = key
    plt.plot(compression_flops, accuracy, marker=marker[i], label = lbl)
plt.xlabel('Compression (FLOPS)')
plt.ylabel('Accuracy')
plt.title('LeNet-5 on MNIST: Accuracy vs theoretical speedup')
plt.grid(True)
plt.legend()

plt.subplot(1,2,2)

for i, (key, results) in enumerate(experiments_results.items()):
    compression_size = results["compression_size"]
    accuracy = results["accuracy"]
    lbl = key
    plt.plot(compression_size, accuracy, marker=marker[i], label = lbl)
plt.xlabel('Compression (Model size)')
plt.ylabel('Accuracy')
plt.title('LeNet-5 on MNIST: Accuracy vs model compression')
plt.grid(True)
plt.legend()

plt.show()
